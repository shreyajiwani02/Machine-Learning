# %% [markdown]
# FILE I/O

# %% [markdown]
# Opening a File

# %%
f = open('/Users/Shreya/Desktop/IPL_context.txt') #open file in current direcotry
f.read()
# Out:
# 'Hey this is organised in UAE, from 2021 sept to oct 2021. Thanks!\n'

# %% [markdown]
# # Python File Modes

# %% [markdown]
# 'r' Open a file for reading. (default)
#
# 'w' Open a file for writing. Creates a new file if it does not exist or truncates the file if it exists.
#
# 'x' Open a file for exclusive creation. If the file already exists, the operation fails.
#
# 'a' Open for appending at the end of the file without truncating it. Creates a new file if it does not exist.
#
# 't' Open in text mode. (default)
#
# 'b' Open in binary mode.
#
# '+' Open a file for updating (reading and writing)

# %%
f = open('/Users/Shreya/Desktop/python_test.txt') #equivalent to 'r' 
f = open('/Users/Shreya/Desktop/python_test.txt', 'r')

# %%
import os

os.chdir('/Users/Shreya/Documents')

f = open('QUAD_meet.txt', 'w')

f.write("QUAD is a four core group team. which helps to secure the indian ocean.")

f.close()

# %% [markdown]
# # Closing a File

# %%
f = open('/Users/Shreya/Desktop/vaccination.txt')
f.close()

# %% [markdown]
# This method is not entirely safe. A safer way is to use a try...finally block.

# %%
'''try:
    f = open("/Users/Shreya/Desktop/vaccination1.txt")
   # perform file operations
    
finally:
   f.close()'''

# %% [markdown]
# # Writing to a File

# %%
os.getenv("/Users/Shreya/Desktop")
f = open("Tesla_mode.txt", "a")
f.write("This is my append line\n")
f.write("it contain one line only\n")
f.close()

# %%
f = open("/Users/Shreya/Desktop/file.py",'x')
f.write("import statistics as st")
f.close()

# %% [markdown]
# This program will create a new file named 'test.txt' if it does not exist. If it does exist, it is overwritten.

# %% [markdown]
# # Reading From a File

# %%
#os.getenv("HOME")
f = open("new_file.csv", "r")
f.read()
# Out:
# '80967XXX90,Wayne,TCS,4\n\n'

# %%
print(os.getcwd())
f = open("custData.csv", "r")
f.read(7)

# %%
#f = open("test.txt","r")
f.read(5)
f.seek(0)
# Out:
# 0

# %% [markdown]
# We can change our current file cursor (position) using the seek() method.
#
# Similarly, the **tell()** method returns our current position (in number of bytes).

# %%
f.tell()
# Out:
# 0

# %%
print(f.read()) #read the entire file

# %% [markdown]
# We can read a file line-by-line using a for loop. This is both efficient and fast.

# %%
f.seek(0)
for line in f:
    print(line)
# Out:
# India has started vaccinating it's citizens from 15th Jan,this is only for certain age category

# %%
f = open("custData.csv", "r")
f.readline()
# Out:
# 'ID,Name,Year\n'

# %%
f.readline()

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()

# %% [markdown]
# The **readlines()** method returns a list of remaining lines of the entire file. All these reading method return empty values when end of file (EOF) is reached.

# %%
f.seek(0)
f.readlines()
# Out:
# ['ID,Name,Year\n',
#  '10,Neil,2017\n',
#  '11,Arnold,2017\n',
#  '12,Neil,2017\n',
#  '13,Mohan,2018\n',
#  '14,Manik,2017\n',
#  '15,Mohan,2017\n',
#  '16,Manik,2017\n',
#  '17,Neil,2017\n',
#  '18,Archi,2018\n',
#  '19,Archi,2018\n',
#  '20,Manik,2017\n',
#  '21,Archi,2018\n',
#  '22,Archi,2018\n']

# %%
f.seek(0)
f.read()
# Out:
# '80967XXX90,Wayne,TCS,4\n80967XXX91,Raju,TM,5\n80967XXX92,Manjunath,MS,6\n\n'

# %% [markdown]
# Renaming And Deleting Files In Python.

# %%
import os

os.chdir("/Users/Shreya/Desktop")
#Rename a file from test.txt to sample.txt
os.rename("custData.csv", "customer.csv")

# %%
f = open("sample.txt", "r")
f.readlines()

# %%
#Delete a file sample.txt
os.remove("test_file")

# %%
f = open("sample.txt", "r")
f.readline()

# %% [markdown]
# Python Directory and File Management

# %% [markdown]
# **Get current Directory**

# %%
os.getcwd()

# %% [markdown]
# **Changing Directory**

# %%
os.chdir("/Users/Shreya/Desktop/")

# %%
os.getcwd()

# %% [markdown]
# **List Directories and Files**

# %%
os.listdir()
# Out:
# ['cloudera-quickstart-vm-5.13.0-0-vmware',
#  'Screenshot 2021-04-12 at 1.02.58 PM.png',
#  'finance.csv',
#  '.DS_Store',
#  'Screenshot 2021-04-06 at 3.34.20 PM.png',
#  'Screenshot 2021-04-05 at 1.32.52 PM.png',
#  '.localized',
#  'IPL.txt',
#  'vacc_2021.txt',
#  'main-qimg-d9683577548d0bdb6e8f0dd6a2000572.png',
#  'persist_File',
#  'custData.csv']

# %% [markdown]
# **Making New Directory**

# %%
os.mkdir('test_py')

# %% [markdown]
# However, note that rmdir() method can only remove empty directories.
#
# In order to remove a non-empty directory we can use the rmtree() method inside the shutil module.

# %%
#os.mkdir('/Users/Shreya/Desktop/test1')
os.chdir('/Users/Shreya/Desktop/test_py/')
f = open("movie_rating.csv",'x')
f.write("'Bahubali',8.9,780.00")
f.close()
#os.chdir("../")
#os.rmdir('test1')

# %%
os.chdir('/Users/Shreya/Desktop')

# %%
os.rmdir('test_py/')

# %%
os.getcwd()
